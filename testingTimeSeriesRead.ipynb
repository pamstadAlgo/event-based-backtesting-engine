# %%
import pandas as pd
from store import ParquetRecordStore

store = ParquetRecordStore(root_dir="data")

df = store.read(
    "valuations_penman_ttm",
    filters=[("symbol", "==", "WLDN:US")]
).sort_values("asof_date")

print(df)
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       2 from store import ParquetRecordStore
#       4 store = ParquetRecordStore(root_dir="data")
# ----> 6 df = store.read(
#       7     "valuations_penman_ttm",
#       8     filters=[("symbol", "==", "WLDN:US")]
#       9 ).sort_values("asof_date")
#      11 print(df)
#
# File ~/Desktop/SideProjects/Valuation/backtesting-engine/event-based-backtesting-engine/store.py:71, in ParquetRecordStore.read(self, dataset, filters)
#      69 if not dataset_path.exists():
#      70     raise FileNotFoundError(f"Dataset not found: {dataset_path}")
# ---> 71 return pd.read_parquet(dataset_path, filters=filters)
#
# ...
