# %%
import pandas_datareader.data as web
from datetime import date, datetime
start = datetime(2002, 12, 1)
end   = datetime.today()

df = web.DataReader("WLDN", "stooq",  start=start, end=end).sort_index()
#df = web.DataReader("VCM", "stooq").sort_index()

print(df)

# target = date(2025, 7, 31)

# try:
#     close = df.loc[target.isoformat(), "Close"]
#     print(f"AAPL close on {target}: {close}")
# except KeyError:
#     print("No price for that date")
# Out:
#                Open     High       Low   Close   Volume
# Date
# 2006-11-20   10.000   10.000   10.0000   10.00        0
# 2006-11-21   10.110   11.990    9.2500   10.56  1731542
# 2006-11-22   10.570   10.890    9.9000   10.64   368465
# 2006-11-24   10.830   10.830   10.5000   10.60    90937
# 2006-11-27   10.750   10.750   10.1100   10.20    86101
# ...             ...      ...       ...     ...      ...
# 2025-12-31  108.430  108.520  103.4800  103.66   316615
# 2026-01-02  104.470  107.140  103.7500  106.66   156928
# 2026-01-05  107.770  111.375  107.6255  109.74   183521
# 2026-01-06  109.790  114.120  105.1184  113.90   605063
# 2026-01-07  114.825  117.000  111.1100  114.29   454144
#
# [4654 rows x 5 columns]

# %%
from priceprovider import StooqPriceProvider
priceProvider = StooqPriceProvider()

example_date = date(2006, 11, 1)


price_date, price = priceProvider.last_close_in_month('WLDN', example_date)

print(f"date: {price_date}, price: {price}")
# Out:
# date: None, price: None
